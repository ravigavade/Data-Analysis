# %% [markdown]
# **Introduction to pandas**

# %%
import pandas as pd

# %%
#creating a static data frame
df=pd.DataFrame([[1,2,3],[4,5,6],[7,8,9]], columns=["A","B","C"])

# %%
#to print the top 5 rows
df.head()
# Out:
#    A  B  C
# 0  1  2  3
# 1  4  5  6
# 2  7  8  9

# %%
#to print the last 5 rows
df.tail()
# Out:
#    A  B  C
# 0  1  2  3
# 1  4  5  6
# 2  7  8  9

# %%
#to acccess the colums
df.columns
# Out:
# Index(['A', 'B', 'C'], dtype='object')

# %%
# to access the indices
df.index.to_list()
# Out:
# [0, 1, 2]

# %%
#provides us with the data strucute(say shape)
df.shape
# Out:
# (3, 3)
